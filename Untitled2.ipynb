# %%
import pandas as pd
import re

# %%
raw_data=open("WhatsApp Chat with AEC Army24.txt","r","encoding") 
raw_string = ' '.join(file.split('\n'))  # converting the list split by newline char. as one whole string as there can be multi-line messages
user_msg = re.split('\d{1,2}/\d{1,2}/\d{2,4},\s\d{1,2}:\d{2}\s[APap][mM]\s-\s', raw_string)

# %%
def rawToDf(file):# file will be pass as a string
    split_formats = {
        '12hr': '\d{1,2}/\d{1,2}/\d{2,4},\s\d{1,2}:\d{2}\s[APap][mM]\s-\s',
        '24hr': '\d{1,2}/\d{1,2}/\d{2,4},\s\d{1,2}:\d{2}\s-\s',
        'custom': ''
    }
    datetime_formats = {
        '12hr': '%d/%m/%Y, %I:%M %p - ',
        '24hr': '%d/%m/%Y, %H:%M - ',
        'custom': ''
    }
# whereever key is wriiten we modify it by writting 12hr bcz we are not passing any key as armument to this function
  # and we don't want the choices for 12hr and 24hr ,we want code for only 12hr.


    raw_string = ' '.join(file.split('\n'))  # converting the list split by newline char. as one whole string as there can be multi-line messages
    user_msg = re.split(split_formats['12hr'], raw_string)[1:]  # splits at all the date-time pattern, resulting in list of all the messages with user names
    date_time = re.findall(split_formats['12hr'], raw_string)  # finds all the date-time patterns

    df = pd.DataFrame({'date_time': date_time, 'user_msg': user_msg})  # exporting it to a df

    # converting date-time pattern which is of type String to type datetime,
    # format is to be specified for the whole string where the placeholders are extracted by the method
    df['date_time'] = pd.to_datetime(df['date_time'], format=datetime_formats['12hr'])

    # split user and msg
    usernames = []
    msgs = []
    for i in df['user_msg']:
        a = re.split('([\w\W]+?):\s', i)
        if (a[1:]):  # user typed messages
            usernames.append(a[1])
            if a[2] == '':
                msgs.append(a[3:])
            else:
                msgs.append(a[2])

        else:  # other notifications in the group(eg: someone was added, some left ...)
            usernames.append("Group Notification")
            msgs.append(a[0])

    # creating new columns
    df['user'] = usernames
    df['Message'] = msgs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 45>()
#      43     df['user'] = usernames
#      44     df['Message'] = msgs
# ---> 45 df
#
# NameError: name 'df' is not defined

# %%
 with open("WhatsApp Chat with AEC Army24.txt", 'r',encoding="utf-8") as raw_data:
        raw_string = raw_data.read().split("\n")
rawTo

# %%
raw_string
# Out:
# ['01/04/2021, 9:29 pm - Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.',
#  '02/04/2021, 11:52 pm - Pranay Gupta: <Media omitted>',
#  '05/04/2021, 10:26 am - Nisha Jhaa: All Students of this batch are advised to join the live online class of Lecture_Engineering Graphics & Design_ES-ME-291 through the following link.',
#  'https://meet.google.com/mna-efbp-gik',
#  '',
#  'Also advised to give the attendance through the following link. ',
#  'https://forms.gle/zPZkbY278jY2g5bQ7',
#  '',
#  '',
#  '',
#  'Both links will be the same for each & every class of Lecture_Engineering Graphics & Design_ES-ME-291.',
#  '08/04/2021, 9:44 am - Pranay Gupta: *HMHU201 ROUTINE*',
#  '----------------------------------------',
#  '*ECE:*',
#  'Tuesday: 11:00am',
#  'Wednesday: 1:00pm',
#  '----------------------------------------',
#  '*CSE (Batch-1):*',
#  'Wednesday: 12:00noon',
#  'Thursday: 2:00pm',
# ...

# %%
for i in raw_string:
    print(i)
# Out:
# 01/04/2021, 9:29 pm - Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.
# 02/04/2021, 11:52 pm - Pranay Gupta: <Media omitted>
# 05/04/2021, 10:26 am - Nisha Jhaa: All Students of this batch are advised to join the live online class of Lecture_Engineering Graphics & Design_ES-ME-291 through the following link.
# https://meet.google.com/mna-efbp-gik
#
# Also advised to give the attendance through the following link.
# https://forms.gle/zPZkbY278jY2g5bQ7
#
#
#
# Both links will be the same for each & every class of Lecture_Engineering Graphics & Design_ES-ME-291.
# 08/04/2021, 9:44 am - Pranay Gupta: *HMHU201 ROUTINE*
# ----------------------------------------
# *ECE:*
# Tuesday: 11:00am
# Wednesday: 1:00pm
# ----------------------------------------
# *CSE (Batch-1):*
# Wednesday: 12:00noon
# Thursday: 2:00pm
# ----------------------------------------
# *CSE (Batch-2):*
# Wednesday: 2:00pm
# ...

# %%
raw_string="".join(raw_string)

# %%
type(raw_string)
# Out:
# str

# %%
raw_string
# Out:
# '01/04/2021, 9:29 pm - Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.02/04/2021, 11:52 pm - Pranay Gupta: <Media omitted>05/04/2021, 10:26 am - Nisha Jhaa: All Students of this batch are advised to join the live online class of Lecture_Engineering Graphics & Design_ES-ME-291 through the following link.https://meet.google.com/mna-efbp-gikAlso advised to give the attendance through the following link. https://forms.gle/zPZkbY278jY2g5bQ7Both links will be the same for each & every class of Lecture_Engineering Graphics & Design_ES-ME-291.08/04/2021, 9:44 am - Pranay Gupta: *HMHU201 ROUTINE*----------------------------------------*ECE:*Tuesday: 11:00amWednesday: 1:00pm----------------------------------------*CSE (Batch-1):*Wednesday: 12:00noonThursday: 2:00pm----------------------------------------*CSE (Batch-2):*Wednesday: 2:00pmThursday: 3:00pm----------------------------------------*IT:*Thursda
# ...
